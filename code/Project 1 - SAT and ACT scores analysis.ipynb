# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 100px">
#
# # Project 1: SAT and ACT scores analysis
#
# # Codes

# %% [markdown]
# ### Contents:
# - [Problem Statement](#Problem-Statement)
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
#     - [1st Dataset - sat_2019_ca](#Data-Import-and-Cleaning-of-1st-Dataset---sat_2019_ca)
#     - [2nd Dataset - act_2019_ca](#Data-Import-and-Cleaning-of-2nd-Dataset---act_2019_ca)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# As education policy advisor for the government of California in the year 2020, I am tasked to look for ways to increase college enrollments, and one aspect to do so is to improve the college admission test results of students.
#
# As majority of California schools enrolled their students in SAT or ACT test, **this project aims to identify insights from graduated students’ performance in the 2019 SAT and ACT tests. And hence to provide recommendations to government to improve college admission test results of students, so as to improve the college enrollment rates.**

# %% [markdown]
# ## Background

# %% [markdown]
# As education policy advisor for the government of California in the year 2020, I am tasked to look for ways to increase college enrollments, and one aspect to do so is to improve the college admission test results of students.
#
# ### California State
# 1. According to [US Census Bureau](#[https://www.census.gov/quickfacts/CA](https://www.census.gov/quickfacts/CA)), California State is the highest population state (~39.5 million, ~12% of US population).
# 2. And every year there will be [~420,000 high school graduates](#https://nces.ed.gov/programs/digest/d16/tables/dt16_219.20.asp) in California.
# 3. However, there are only [63%](#https://edpolicyinca.org/sites/default/files/Statewide%20NSC%20Report%20Final%20Online.pdf) of high school students in California able to enroll into college.
#
# ### College Admission Test
#
# - Most California schools enrolled their students in taking SAT Test [(63%)](#https://blog.prepscholar.com/average-sat-scores-by-state-most-recent) and / or ACT test [(23%)](#https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows).
#
#
# - In SAT Exam, 2 subjects are to be taken by registered students, which are [Evidence-based Reading and Writing (ERW) and Mathematics](#https://collegereadiness.collegeboard.org/sat/inside-the-test). And to assess the students' readiness for college, SAT Board have published a College and Career Readiness benchmark scores for both subjects [(ERW >= 480, Math >=530)](#https://collegereadiness.collegeboard.org/about/scores/benchmarks). Students with scores >= College and Career Readiness benchmark scores will have a 75% chance of earning at least a C in 1st semester in college for credit bearing courses.
#
#
# - In ACT Exam, 4 subjects are to be taken by registered students, which are [English, Math, Reading, Science](#https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html). ACT has a composite score to assess the students, and in recent years, [ACT Composite score = 21](#https://blog.prepscholar.com/what-is-a-good-act-score-a-bad-act-score-an-excellent-act-score) is the benchmark where students with this composite score is at the 50th percentile of all test takers.

# %% [markdown]
# ## Datasets Used

# %% [markdown]
# I used the dataset of sat_2019_ca.csv and act_2019_ca.csv for my analysis.
#
# sat_2019_ca.csv contains information of year 11 and year 12 students performance in the SAT test for the state of California in the year 2019.
#
# act_2019_ca.csv contains information of students performance in the ACT test for the state of California in the year 2019.

# %% [markdown]
# ---
# # Part 1
#
# Part 1 are coding challenges that requires knowledge of writing codes in Python.
#
# ---

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# A function to calculate mean of values passed into the function in a list

def calculate_mean(n):                          # Function is named as 'calculate_mean' and take in 1 variable as'n'
    count = 0                                   # Initialize a variable 'count' with integer 0.
    for i in range (0,len(n)):                  # For every item in range of 0 to length of 'n' being passed in,
        count += n[i]                           # add the item to the variable 'count'
    return (count/len(n))                       # Return mean, which is 'count' divided by the amount of values present in 'n'.

# %%
# A random list of numbers, 'random_list' to test the function above.
random_list = [1,23,3,44,5,67,7,82,9,100]

# %%
#Output by function 'calculate_mean'
calculate_mean(random_list)

# %%
#Validation of output of function == mean of list 'random_list'
(1+23+3+44+5+67+7+82+9+100)/10

#Output is equal to output of function, the function works.

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# A function to calculate standard deviation of values passed into the function in a list.

def calculate_std_dev(n):                               # Function is named as "calculate_std_dev" and take in 1 variable as'n'
    sum_ = 0                                            # Initialize a variable 'sum_' with integer 0.
    for i in range (0,len(n)):                          # For every item in range of 0 to length of 'n' being passed in,
        sum_ += (n[i] - calculate_mean(n))**2           # sum the square of (value of n - calculated mean of n)
    return (sum_ / (len(n)-1))**0.5                     # Return the square root of ('sum_' / len(n)-1) to get std dev number.

# %%
#Output by function 'calculate_std_dev'
calculate_std_dev(random_list)

# %%
#Validation of output of function == standard deviation of list 'random_list' using statistics library stdev method.
import statistics                            # import statistics python library
statistics.stdev(random_list)                # Calculate the std dev of the list "random_list".

#Output is equal to output of function, the function works.

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# A function to convert percentage to decimal approximation of the percent.

def percentage_to_decimals_convert(n):          # Function is named as "percentage_to_decimals_convert" and take in 1 str variable as'n'
    new_n = n.replace('%','')                   # Replace all '%'sign in the string 'n' to blank, and store it in 'new_n' variable.
    return (float(new_n) /100)                  # Return the division of new_n in float type with 100.

# %%
#Output by function 'percentage_to_decimals_convert'
percentage_to_decimals_convert('30.5%')

# Output matches expectation, the function works

# %% [markdown]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stats

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ## Data Import and Cleaning of 1st Dataset - sat_2019_ca

# %% [markdown]
# ### Import Dataset

# %%
# Import dataset of sat_2019_ca (SAT score details in California in year 2018-2019)
sat_2019 = pd.read_csv('..\dataset\sat_2019_ca.csv')

# %% [markdown]
# ### 1. Display data of 1st 5 rows

# %%
# Print 1st 5 rows of dataframe
sat_2019.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
#Check number of rows and columns in dataset
sat_2019.shape
# Out:
# (2580, 26)

# %% [markdown]
# ### 2. Check for Missing Values and Filter Rows with Missing Values

# %%
# Check for missing values
sat_2019.isnull().sum()
# Out:
# CDS                         1
# CCode                       1
# CDCode                      1
# SCode                       1
# RType                       1
# SName                     598
# DName                      59
# CName                       1
# Enroll12                    1
# NumTSTTakr12                1
# NumERWBenchmark12         276
# PctERWBenchmark12         276
# NumMathBenchmark12        276
# PctMathBenchmark12        276
# Enroll11                    1
# NumTSTTakr11                1
# NumERWBenchmark11         311
# PctERWBenchmark11         311
# NumMathBenchmark11        311
# PctMathBenchmark11        311
# TotNumBothBenchmark12     276
# PctBothBenchmark12        276
# TotNumBothBenchmark11     311
# PctBothBenchmark11        311
# Year                        1
# Unnamed: 25              2580
# dtype: int64

# %%
# Filter away rows with missing values. 
# From above, can see 'SName' column has highest *unique* missing values (598), 
# followed by columns indicating Year 11 (311),
# followed by columns indicating Year 12 (276).
# So, I just chose 3 columns from above categories to filter.
# Store it in new dataframe 'new_sat_2019'
new_sat_2019 = sat_2019.dropna(axis=0, inplace=False,subset=['SName','NumERWBenchmark12','NumERWBenchmark11'])

# %%
# Recheck number of rows and columns in dataset.
new_sat_2019.shape
# Out:
# (1602, 26)

# %%
# Recheck for missing values in the rest of columns
new_sat_2019.isnull().sum()
# Out:
# CDS                         0
# CCode                       0
# CDCode                      0
# SCode                       0
# RType                       0
# SName                       0
# DName                       0
# CName                       0
# Enroll12                    0
# NumTSTTakr12                0
# NumERWBenchmark12           0
# PctERWBenchmark12           0
# NumMathBenchmark12          0
# PctMathBenchmark12          0
# Enroll11                    0
# NumTSTTakr11                0
# NumERWBenchmark11           0
# PctERWBenchmark11           0
# NumMathBenchmark11          0
# PctMathBenchmark11          0
# TotNumBothBenchmark12       0
# PctBothBenchmark12          0
# TotNumBothBenchmark11       0
# PctBothBenchmark11          0
# Year                        0
# Unnamed: 25              1602
# dtype: int64

# %% [markdown]
# ### 3. Check for any obvious issues with the observations

# %%
# Print 1st 5 rows of dataframe
new_sat_2019.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
# 5  1.964734e+13   19.0  1964733.0  6061451.0     S   Foshay Learning Center
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
# 5  Los Angeles Unified  Los Angeles     166.0         106.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %% [markdown]
# #### Problem 1: There are rows of empty values stored as * at all numerical columns

# %%
# Filter away rows with * values in all columns
for items in range(0,len(new_sat_2019.columns)):                                      # For every item in range of 0 to the amount of columns,
    new_sat_2019 = new_sat_2019.loc[new_sat_2019[new_sat_2019.columns[items]] != '*']  # filter rows with data cells with '*'

# %%
# Recheck number of rows and columns in dataset.
new_sat_2019.shape
# Out:
# (1199, 26)

# %% [markdown]
# #### Problem 2: The max number of enrollment and number of Test Taken is abnormal High

# %%
# Checking the max value for data in each column
new_sat_2019.max()

# The max number of enrollment and number of Test Taken is abnormal High
# Out:
# CDS                                    58727695838305.0
# CCode                                              58.0
# CDCode                                        5872769.0
# SCode                                         6120893.0
# RType                                                 X
# SName                                     e3 Civic High
# DName                    Yucaipa-Calimesa Joint Unified
# CName                                              Yuba
# Enroll12                                       489650.0
# NumTSTTakr12                                   170411.0
# NumERWBenchmark12                                    99
# PctERWBenchmark12                                 98.72
# NumMathBenchmark12                                   99
# PctMathBenchmark12                                98.98
# Enroll11                                       474843.0
# NumTSTTakr11                                   206642.0
# NumERWBenchmark11                                    99
# ...

# %%
# Found that the abnormal high value row is the last row, which states the total amount of figures in california
new_sat_2019.tail()
# Out:
#                CDS  CCode     CDCode      SCode RType                   SName  \
# 1973  4.570136e+13   45.0  4570136.0  4532750.0     S         Enterprise High
# 1976  2.365623e+13   23.0  2365623.0  2335487.0     S            Willits High
# 1979  3.367033e+13   33.0  3367033.0   110627.0     S  Eleanor Roosevelt High
# 1980  5.075550e+13   50.0  5075549.0  5032651.0     S            Hughson High
# 2036  0.000000e+00    0.0        0.0        0.0     X     State of California
#
#                      DName                CName  Enroll12  NumTSTTakr12  ...  \
# 1973     Shasta Union High               Shasta     302.0          54.0  ...
# 1976       Willits Unified            Mendocino      76.0          18.0  ...
# 1979  Corona-Norco Unified            Riverside    1083.0         543.0  ...
# 1980       Hughson Unified           Stanislaus     150.0          40.0  ...
# 2036   State of California  State of California  489650.0      170411.0  ...
#
# ...

# %%
# Filter the last row
new_sat_2019 = new_sat_2019.loc[new_sat_2019['Enroll12'] != 489650]

# %%
# Recheck number of rows and columns in dataset.
new_sat_2019.shape
# Out:
# (1198, 26)

# %%
# Recheck the max value for data in each column. The rest of data seems normal.
new_sat_2019.max().head(26)
# Out:
# CDS                                    58727695838305.0
# CCode                                              58.0
# CDCode                                        5872769.0
# SCode                                         6120893.0
# RType                                                 S
# SName                                     e3 Civic High
# DName                    Yucaipa-Calimesa Joint Unified
# CName                                              Yuba
# Enroll12                                         1135.0
# NumTSTTakr12                                      932.0
# NumERWBenchmark12                                    99
# PctERWBenchmark12                                 98.72
# NumMathBenchmark12                                   99
# PctMathBenchmark12                                98.98
# Enroll11                                         1218.0
# NumTSTTakr11                                     1058.0
# NumERWBenchmark11                                    99
# ...

# %% [markdown]
# ### 4. Display Data Types of each Column and convert data types

# %%
#Checking data types for each column
new_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198 entries, 2 to 1980
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    1198 non-null   float64
#  1   CCode                  1198 non-null   float64
#  2   CDCode                 1198 non-null   float64
#  3   SCode                  1198 non-null   float64
#  4   RType                  1198 non-null   object
#  5   SName                  1198 non-null   object
#  6   DName                  1198 non-null   object
#  7   CName                  1198 non-null   object
#  8   Enroll12               1198 non-null   float64
#  9   NumTSTTakr12           1198 non-null   float64
#  10  NumERWBenchmark12      1198 non-null   object
#  11  PctERWBenchmark12      1198 non-null   object
#  12  NumMathBenchmark12     1198 non-null   object
#  13  PctMathBenchmark12     1198 non-null   object
# ...

# %%
#Reset the index of dataset after filtering
new_sat_2019.reset_index(inplace=True,drop=True,col_fill='index')

# %%
# Print columns of dataframe
sat_2019.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12', 'PctERWBenchmark12',
#        'NumMathBenchmark12', 'PctMathBenchmark12', 'Enroll11', 'NumTSTTakr11',
#        'NumERWBenchmark11', 'PctERWBenchmark11', 'NumMathBenchmark11',
#        'PctMathBenchmark11', 'TotNumBothBenchmark12', 'PctBothBenchmark12',
#        'TotNumBothBenchmark11', 'PctBothBenchmark11', 'Year', 'Unnamed: 25'],
#       dtype='object')

# %%
#Converting the column datatype of numerical columns to float
for i in range (8,24):                                                                           # For every columns from 8th to 23rd,
    new_sat_2019[new_sat_2019.columns[i]]= new_sat_2019[new_sat_2019.columns[i]].astype(float)   # convert datatype to float

# %%
# Rechecking data types for each column
new_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1198 entries, 0 to 1197
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    1198 non-null   float64
#  1   CCode                  1198 non-null   float64
#  2   CDCode                 1198 non-null   float64
#  3   SCode                  1198 non-null   float64
#  4   RType                  1198 non-null   object
#  5   SName                  1198 non-null   object
#  6   DName                  1198 non-null   object
#  7   CName                  1198 non-null   object
#  8   Enroll12               1198 non-null   float64
#  9   NumTSTTakr12           1198 non-null   float64
#  10  NumERWBenchmark12      1198 non-null   float64
#  11  PctERWBenchmark12      1198 non-null   float64
#  12  NumMathBenchmark12     1198 non-null   float64
#  13  PctMathBenchmark12     1198 non-null   float64
# ...

# %% [markdown]
# ### 5. Rename Columns

# %%
# Lowercasifying all letters in column names
new_sat_2019.columns = new_sat_2019.columns.str.lower()

# Renaming all neccessary columns
new_sat_2019 = new_sat_2019.rename(columns = {
    'sname':'school_name',
    'dname':'district_name',
    'cname':'county_name',
    'enroll12':'no_of_year12_enrollment',
    'numtsttakr12':'no_of_year12_testtakers',
    'numerwbenchmark12':'no_of_year12_above_erw_benchmark',
    'pcterwbenchmark12':'pct_of_year12_above_erw_benchmark',
    'nummathbenchmark12':'no_of_year12_above_math_benchmark',
    'pctmathbenchmark12':'pct_of_year12_above_math_benchmark',
    'enroll11':'no_of_year11_enrollment',
    'numtsttakr11':'no_of_year11_testtakers',
    'numerwbenchmark11':'no_of_year11_above_erw_benchmark',
    'pcterwbenchmark11':'pct_of_year11_above_erw_benchmark',
    'nummathbenchmark11':'no_of_year11_above_math_benchmark',
    'pctmathbenchmark11':'pct_of_year11_above_math_benchmark',
    'totnumbothbenchmark12':'no_of_year12_above_both_benchmark',
    'pctbothbenchmark12':'pct_of_year12_above_both_benchmark',
    'totnumbothbenchmark11':'no_of_year11_above_both_benchmark',
    'pctbothbenchmark11':'pct_of_year11_above_both_benchmark',
})

# %% [markdown]
# ### 6. Drop Unnecessary columns

# %%
#Check current columns present
new_sat_2019.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'school_name',
#        'district_name', 'county_name', 'no_of_year12_enrollment',
#        'no_of_year12_testtakers', 'no_of_year12_above_erw_benchmark',
#        'pct_of_year12_above_erw_benchmark',
#        'no_of_year12_above_math_benchmark',
#        'pct_of_year12_above_math_benchmark', 'no_of_year11_enrollment',
#        'no_of_year11_testtakers', 'no_of_year11_above_erw_benchmark',
#        'pct_of_year11_above_erw_benchmark',
#        'no_of_year11_above_math_benchmark',
#        'pct_of_year11_above_math_benchmark',
#        'no_of_year12_above_both_benchmark',
#        'pct_of_year12_above_both_benchmark',
#        'no_of_year11_above_both_benchmark',
#        'pct_of_year11_above_both_benchmark', 'year', 'unnamed: 25'],
#       dtype='object')

# %%
# Drop unnecessary columns
new_sat_2019.drop(['cds','ccode','cdcode', 'scode', 'rtype','unnamed: 25','year'], axis=1, inplace=True)

# %%
# Recheck columns present
new_sat_2019.columns
# Out:
# Index(['school_name', 'district_name', 'county_name',
#        'no_of_year12_enrollment', 'no_of_year12_testtakers',
#        'no_of_year12_above_erw_benchmark', 'pct_of_year12_above_erw_benchmark',
#        'no_of_year12_above_math_benchmark',
#        'pct_of_year12_above_math_benchmark', 'no_of_year11_enrollment',
#        'no_of_year11_testtakers', 'no_of_year11_above_erw_benchmark',
#        'pct_of_year11_above_erw_benchmark',
#        'no_of_year11_above_math_benchmark',
#        'pct_of_year11_above_math_benchmark',
#        'no_of_year12_above_both_benchmark',
#        'pct_of_year12_above_both_benchmark',
#        'no_of_year11_above_both_benchmark',
#        'pct_of_year11_above_both_benchmark'],
#       dtype='object')

# %% [markdown]
# ### 7. Save Dataset as CSV

# %%
#Save dataset to csv
new_sat_2019.to_csv('..\dataset\\2019_SAT_California.csv', index = False)

# %% [markdown]
# ## Data Import and Cleaning of 2nd Dataset - act_2019_ca

# %% [markdown]
# ### Import Dataset

# %%
# Import dataset of act_2019_ca (ACT score details in California in year 2018-2019)
act_2019 = pd.read_csv('..\dataset\\act_2019_ca.csv')

# %% [markdown]
# ### 1. Display data of 1st 5 rows

# %%
# Print 1st 5 rows of dataframe
act_2019.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
#Check number of rows and columns in dataset
act_2019.shape
# Out:
# (2310, 18)

# %% [markdown]
# ### 2. Check for Missing Values and Filter Rows with Missing Values

# %%
# Check for missing values
act_2019.isnull().sum()
# Out:
# CDS               1
# CCode             1
# CDCode            1
# SCode           523
# RType             1
# SName           581
# DName            59
# CName             1
# Enroll12          1
# NumTstTakr        1
# AvgScrRead      357
# AvgScrEng       357
# AvgScrMath      357
# AvgScrSci       357
# NumGE21         357
# PctGE21         357
# Year              1
# Unnamed: 17    2310
# dtype: int64

# %%
# Filter away rows with missing values. 
# From above, can see 'SName' column has highest *unique* missing values (581), 
# followed by columns indicating Average Score (357),
# So, I just chose 2 columns from above categories to filter.
# Store it in new dataframe 'new_act_2019'
new_act_2019 = act_2019.dropna(axis=0, inplace=False,subset=['SName','AvgScrRead'])

# %%
# Recheck number of rows and columns in dataset. The number of rows should have 2310 - 581 = 1729 rows.
new_act_2019.shape
# Out:
# (1437, 18)

# %%
# Recheck for missing values in the rest of columns
new_act_2019.isnull().sum()
# Out:
# CDS               0
# CCode             0
# CDCode            0
# SCode             0
# RType             0
# SName             0
# DName             0
# CName             0
# Enroll12          0
# NumTstTakr        0
# AvgScrRead        0
# AvgScrEng         0
# AvgScrMath        0
# AvgScrSci         0
# NumGE21           0
# PctGE21           0
# Year              0
# Unnamed: 17    1437
# dtype: int64

# %% [markdown]
# ### 3. Check for any obvious issues with the observations

# %%
# Print 1st 5 rows of dataframe
new_act_2019.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
# 5  1.976968e+13   19.0  1976968.0   109926.0     S
# 6  1.964733e+13   19.0  1964733.0   126615.0     S
# 7  1.964246e+13   19.0  1964246.0   126003.0     S
#
#                                                SName  \
# 3                               Abraham Lincoln High
# 4                        Abraham Lincoln Senior High
# 5                            Academia Avance Charter
# 6  Academies of Education and Empowerment at Cars...
# 7                   Academies of the Antelope Valley
#
#                            DName        CName  Enroll12  NumTstTakr  \
# 3               San Jose Unified  Santa Clara     463.0        53.0
# 4            Los Angeles Unified  Los Angeles     226.0        19.0
# 5  SBE - Academia Avance Charter  Los Angeles      65.0        33.0
# ...

# %% [markdown]
# #### Problem 1: There are rows of empty values stored as * at all numerical columns

# %%
# Filter away rows with '*' values in all columns
for items in range(0,len(new_act_2019.columns)):                                      # For every item in range of 0 to the amount of columns,
    new_act_2019 = new_act_2019.loc[new_act_2019[new_act_2019.columns[items]] != '*']  # filter rows with data cells with '*'

# %%
# Recheck number of rows and columns in dataset.
new_act_2019.shape
# Out:
# (1017, 18)

# %% [markdown]
# #### Problem 2: The max number of enrollment and number of Test Taken is abnormal High

# %%
# Checking the max value for data in each column
new_act_2019.max()

# The max number of enrollment and number of Test Takers is abnormal High
# Out:
# CDS                          58727695838305.0
# CCode                                    58.0
# CDCode                              5872769.0
# SCode                               6120158.0
# RType                                       X
# SName                            Yucaipa High
# DName          Yucaipa-Calimesa Joint Unified
# CName                                    Yuba
# Enroll12                             489650.0
# NumTstTakr                            82668.0
# AvgScrRead                                 32
# AvgScrEng                                  32
# AvgScrMath                                 32
# AvgScrSci                                  31
# NumGE21                                    99
# PctGE21                                 98.18
# Year                                  2018-19
# Unnamed: 17                               NaN
# dtype: object

# %%
# Filter away the abnormal row
new_act_2019 = new_act_2019.loc[new_act_2019['Enroll12'] != 489650]

# %%
# Recheck number of rows and columns in dataset.
new_act_2019.shape
# Out:
# (1016, 18)

# %%
# Recheck the max value for data in each column. The rest of data seems normal.
new_act_2019.max().head(26)
# Out:
# CDS                          58727695838305.0
# CCode                                    58.0
# CDCode                              5872769.0
# SCode                               6120158.0
# RType                                       S
# SName                            Yucaipa High
# DName          Yucaipa-Calimesa Joint Unified
# CName                                    Yuba
# Enroll12                               1135.0
# NumTstTakr                              512.0
# AvgScrRead                                 32
# AvgScrEng                                  32
# AvgScrMath                                 32
# AvgScrSci                                  31
# NumGE21                                    99
# PctGE21                                 98.18
# Year                                  2018-19
# Unnamed: 17                               NaN
# dtype: object

# %% [markdown]
# ### 4. Display Data Types of each Column and convert data types

# %%
#Checking data types for each column
new_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 3 to 2306
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          1016 non-null   float64
#  1   CCode        1016 non-null   float64
#  2   CDCode       1016 non-null   float64
#  3   SCode        1016 non-null   float64
#  4   RType        1016 non-null   object
#  5   SName        1016 non-null   object
#  6   DName        1016 non-null   object
#  7   CName        1016 non-null   object
#  8   Enroll12     1016 non-null   float64
#  9   NumTstTakr   1016 non-null   float64
#  10  AvgScrRead   1016 non-null   object
#  11  AvgScrEng    1016 non-null   object
#  12  AvgScrMath   1016 non-null   object
#  13  AvgScrSci    1016 non-null   object
#  14  NumGE21      1016 non-null   object
#  15  PctGE21      1016 non-null   object
#  16  Year         1016 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
#Reset the index of dataset after filtering
new_act_2019.reset_index(inplace=True,drop=True,col_fill='index')

# %%
# Print columns of dataframe
new_act_2019.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTstTakr', 'AvgScrRead', 'AvgScrEng', 'AvgScrMath',
#        'AvgScrSci', 'NumGE21', 'PctGE21', 'Year', 'Unnamed: 17'],
#       dtype='object')

# %%
#Converting the column datatype of numerical columns to float
for i in range (8,16):                                                                           # For every columns from 8th to 15th,
    new_act_2019[new_act_2019.columns[i]]= new_act_2019[new_act_2019.columns[i]].astype(float)   # convert datatype to float

# %%
# Rechecking data types for each column
new_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          1016 non-null   float64
#  1   CCode        1016 non-null   float64
#  2   CDCode       1016 non-null   float64
#  3   SCode        1016 non-null   float64
#  4   RType        1016 non-null   object
#  5   SName        1016 non-null   object
#  6   DName        1016 non-null   object
#  7   CName        1016 non-null   object
#  8   Enroll12     1016 non-null   float64
#  9   NumTstTakr   1016 non-null   float64
#  10  AvgScrRead   1016 non-null   float64
#  11  AvgScrEng    1016 non-null   float64
#  12  AvgScrMath   1016 non-null   float64
#  13  AvgScrSci    1016 non-null   float64
#  14  NumGE21      1016 non-null   float64
#  15  PctGE21      1016 non-null   float64
#  16  Year         1016 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %% [markdown]
# ### 5. Rename Columns

# %%
# Lowercasifying all letters in column names
new_act_2019.columns = new_act_2019.columns.str.lower()

# Renaming all neccessary columns
new_act_2019 = new_act_2019.rename(columns = {
    'sname':'school_name',
    'dname':'district_name',
    'cname':'county_name',
    'enroll12':'no_of_year12_enrollment',
    'numtsttakr':'no_of_testtakers',
    'avgscrread':'avg_score_for_reading',
    'avgscreng':'avg_score_for_english',
    'avgscrmath':'avg_score_for_math',
    'avgscrsci':'avg_score_for_science',
    'numge21':'no_of_testtakers_having_>=21_compositescr',
    'pctge21':'pct_of_testtakers_having_>=21_compositescr',
})

# %% [markdown]
# ### 6. Drop Unnecessary columns

# %%
#Check current columns present
new_act_2019.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'school_name',
#        'district_name', 'county_name', 'no_of_year12_enrollment',
#        'no_of_testtakers', 'avg_score_for_reading', 'avg_score_for_english',
#        'avg_score_for_math', 'avg_score_for_science',
#        'no_of_testtakers_having_>=21_compositescr',
#        'pct_of_testtakers_having_>=21_compositescr', 'year', 'unnamed: 17'],
#       dtype='object')

# %%
# Drop unnecessary columns
new_act_2019.drop(['cds','ccode','cdcode', 'scode', 'rtype','unnamed: 17','year'], axis=1, inplace=True)

# %%
# Recheck columns present
new_act_2019.columns
# Out:
# Index(['school_name', 'district_name', 'county_name',
#        'no_of_year12_enrollment', 'no_of_testtakers', 'avg_score_for_reading',
#        'avg_score_for_english', 'avg_score_for_math', 'avg_score_for_science',
#        'no_of_testtakers_having_>=21_compositescr',
#        'pct_of_testtakers_having_>=21_compositescr'],
#       dtype='object')

# %% [markdown]
# ### 7. Save Dataset as CSV

# %%
#Save dataset to csv
new_act_2019.to_csv('..\dataset\\2019_ACT_California.csv', index = False)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Summary Statistics

# %%
# Print the summary statistics for 2019_SAT dataset
new_sat_2019.describe()
# Out:
#        no_of_year12_enrollment  no_of_year12_testtakers  \
# count              1198.000000              1198.000000
# mean                341.508347               138.655259
# std                 209.944022               106.173762
# min                  25.000000                15.000000
# 25%                 141.000000                60.000000
# 50%                 339.000000               113.000000
# 75%                 498.000000               186.000000
# max                1135.000000               932.000000
#
#        no_of_year12_above_erw_benchmark  pct_of_year12_above_erw_benchmark  \
# count                       1198.000000                        1198.000000
# mean                          95.383139                          67.391085
# std                           76.676621                          20.773616
# min                            2.000000                           2.470000
# 25%                           36.000000                          51.867500
# ...

# %%
# Print the summary statistics for 2019_ACT dataset
new_act_2019.describe()
# Out:
#        no_of_year12_enrollment  no_of_testtakers  avg_score_for_reading  \
# count              1016.000000       1016.000000            1016.000000
# mean                371.831693         79.144685              21.870079
# std                 206.213129         66.574849               3.823038
# min                   0.000000         15.000000              12.000000
# 25%                 173.000000         33.000000              19.000000
# 50%                 382.000000         58.000000              22.000000
# 75%                 524.000000        105.000000              25.000000
# max                1135.000000        512.000000              32.000000
#
#        avg_score_for_english  avg_score_for_math  avg_score_for_science  \
# count            1016.000000         1016.000000            1016.000000
# mean               21.017717           21.270669              21.189961
# std                 4.209031            3.499833               3.335189
# ...

# %% [markdown]
# ### 2. Dictionary Comprehension

# %%
# Check new_sat_2019 columns
new_sat_2019.columns
# Out:
# Index(['school_name', 'district_name', 'county_name',
#        'no_of_year12_enrollment', 'no_of_year12_testtakers',
#        'no_of_year12_above_erw_benchmark', 'pct_of_year12_above_erw_benchmark',
#        'no_of_year12_above_math_benchmark',
#        'pct_of_year12_above_math_benchmark', 'no_of_year11_enrollment',
#        'no_of_year11_testtakers', 'no_of_year11_above_erw_benchmark',
#        'pct_of_year11_above_erw_benchmark',
#        'no_of_year11_above_math_benchmark',
#        'pct_of_year11_above_math_benchmark',
#        'no_of_year12_above_both_benchmark',
#        'pct_of_year12_above_both_benchmark',
#        'no_of_year11_above_both_benchmark',
#        'pct_of_year11_above_both_benchmark'],
#       dtype='object')

# %%
# Dictionary comprehension for sd of new_sat_2019 df from column 3 to column 18 (numerical columns)
sd_sat = {str(new_sat_2019.columns[x]): calculate_std_dev(new_sat_2019.loc[:,new_sat_2019.columns[x]]) for x in range(3,19)}

# Checking results of sd
sd_sat
# Out:
# {'no_of_year12_enrollment': 209.94402209033785,
#  'no_of_year12_testtakers': 106.17376176552968,
#  'no_of_year12_above_erw_benchmark': 76.67662101334548,
#  'pct_of_year12_above_erw_benchmark': 20.773616186920027,
#  'no_of_year12_above_math_benchmark': 63.8856639067913,
#  'pct_of_year12_above_math_benchmark': 23.59242820345267,
#  'no_of_year11_enrollment': 211.44262795797783,
#  'no_of_year11_testtakers': 142.28922285188173,
#  'no_of_year11_above_erw_benchmark': 101.22240226239951,
#  'pct_of_year11_above_erw_benchmark': 22.1897695919579,
#  'no_of_year11_above_math_benchmark': 88.90719889515972,
#  'pct_of_year11_above_math_benchmark': 27.221902751810966,
#  'no_of_year12_above_both_benchmark': 61.70227502578904,
#  'pct_of_year12_above_both_benchmark': 23.600004628725483,
#  'no_of_year11_above_both_benchmark': 87.18471428598019,
#  'pct_of_year11_above_both_benchmark': 27.410484082347818}

# %%
# Check new_act_2019 columns
new_act_2019.columns
# Out:
# Index(['school_name', 'district_name', 'county_name',
#        'no_of_year12_enrollment', 'no_of_testtakers', 'avg_score_for_reading',
#        'avg_score_for_english', 'avg_score_for_math', 'avg_score_for_science',
#        'no_of_testtakers_having_>=21_compositescr',
#        'pct_of_testtakers_having_>=21_compositescr'],
#       dtype='object')

# %%
# Dictionary comprehension for sd of new_act_2019 df from column 3 to column 10 (numerical columns)
sd_act = {str(new_act_2019.columns[x]): calculate_std_dev(new_act_2019.loc[:,new_act_2019.columns[x]]) for x in range(3,11)}

# Checking results of sd
sd_act
# Out:
# {'no_of_year12_enrollment': 206.21312859135955,
#  'no_of_testtakers': 66.57484940057007,
#  'avg_score_for_reading': 3.8230375555870926,
#  'avg_score_for_english': 4.209031001640473,
#  'avg_score_for_math': 3.4998333450656474,
#  'avg_score_for_science': 3.335188947967636,
#  'no_of_testtakers_having_>=21_compositescr': 50.11133920636322,
#  'pct_of_testtakers_having_>=21_compositescr': 26.534075998326855}

# %% [markdown]
# ### 3. Investigate trends in the data.

# %% [markdown]
# #### Which California counties is the bottom 5 in terms of median percentage of Year 12 students obtain above benchmark for both Evidence-based Reading and Writing & Math in 2019 SAT test?

# %%
# Aggregate the SAT dataset with 'county_name' column, and assess the max, min, mean, median of the pct of year 12 above both benchmark
# Sort the values according to median in ascending order as median is less likely to be skew by outlier data
# Show the top 5 counties with lowest median 
new_sat_2019.groupby('county_name')['pct_of_year12_above_both_benchmark'].agg(['max','min','mean','median','std']).sort_values('median',ascending=True).head(5)
# Out:
#                max    min       mean  median        std
# county_name
# Colusa       14.29   0.00   7.145000   7.145  10.104556
# Glenn        43.75  16.00  26.090000  18.520  15.345824
# Fresno       88.16   0.00  32.800000  26.345  22.228373
# Los Angeles  98.75   0.00  32.707834  27.930  23.241930
# Monterey     77.97   7.55  34.576429  29.345  20.605738

# %% [markdown]
# In terms of median percentage of Year 12 students obtain above benchmark for both Evidence-based Reading and Writing & Math in 2019 SAT test, the bottom 5 California counties are **Colusa**, **Glenn**, **Fresno**, **Los Angeles** and **Monterey**, with Colusa being the last, Glenn being the 2nd last, etc.

# %% [markdown]
# #### Which California counties is the bottom 5 in terms of median percentage of students obtaining >=21 composite scores in 2019 ACT test?

# %%
# Aggregate the SAT dataset with 'county_name' column, and assess the max, min, mean, median of the pct of year 12 above both benchmark
# Sort the values according to median in ascending order as median is less likely to be skew by outlier data
# Show the top 5 counties with lowest median 
new_act_2019.groupby('county_name')['pct_of_testtakers_having_>=21_compositescr'].agg(['max','min','mean','median','std']).sort_values('median',ascending=True).head(5)
# Out:
#                max    min       mean  median        std
# county_name
# Modoc        25.00   6.67  15.835000  15.835  12.961267
# Fresno       91.86   0.00  36.282963  25.710  27.978976
# Monterey     83.87   9.43  37.931538  27.870  23.251123
# Tehama       41.72  23.68  31.533333  29.200   9.243578
# Lake         38.89  22.22  30.555000  30.555  11.787470

# %% [markdown]
# In terms of median percentage of students obtaining >= 21 composite scores in 2019 SAT test, the bottom 5 California counties are **Modoc**, **Fresno**, **Monterey**, **Tehama** and **Lake**, with Modoc being the last, Fresno being the 2nd last, etc.

# %% [markdown]
# #### Masking ( Boolean filtering) example

# %%
# only show data with 'pct_of_year12_above_both_benchmark' >50
df1 = new_sat_2019['pct_of_year12_above_both_benchmark'] > 50

# %%
# Show some rows to confirm
new_sat_2019[df1].head()
# Out:
#            school_name              district_name  county_name  \
# 3   Mission Viejo High  Saddleback Valley Unified       Orange
# 14    New West Charter     SBE - New West Charter  Los Angeles
# 15    Mark Keppel High           Alhambra Unified  Los Angeles
# 16   Nevada Union High    Nevada Joint Union High       Nevada
# 17     University High             Irvine Unified       Orange
#
#     no_of_year12_enrollment  no_of_year12_testtakers  \
# 3                     562.0                    190.0
# 14                     90.0                     47.0
# 15                    579.0                    269.0
# 16                    353.0                     89.0
# 17                    633.0                    205.0
#
#     no_of_year12_above_erw_benchmark  pct_of_year12_above_erw_benchmark  \
# 3                              161.0                              84.74
# 14                              43.0                              91.49
# ...

# %% [markdown]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ## Data Visualization

# %%
#import seaborn and matplotlib library for data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style use to look nicer
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# ### SAT 2019 Data Visualization

# %% [markdown]
# #### Plotting Heatmap

# %%
# Plotting a heatmap for new_sat_2019 dataset to visualize correlation between columns
plt.figure(figsize=(14,14))                             # Set the figure size to 14 x 14
sns.set_context('paper',font_scale=1.4)                 # Set context of seaborn to 'paper' and font scale to 1.4

# to create heatmap, need corr matrix
new_sat_2019_mx = new_sat_2019.corr()                   # Setting up a correlation matrix of the new_sat_2019 dataset

sns.heatmap(new_sat_2019_mx,annot= True,cmap='Reds')    # Plotting heatmap with annonations, and with cmap in red colour

plt.title('Heatmap for new_sat_2019 dataset to visualize correlation between columns')  #Add title to the heatmap
# Out:
# Text(0.5, 1.0, 'Heatmap for new_sat_2019 dataset to visualize correlation between columns')

# %% [markdown]
# #### Plotting Histogram

# %%
# Plotting histogram on the number of Year 12 testtakers for each school
new_sat_2019['no_of_year12_testtakers'].plot(kind='hist',bins=20,figsize=(5,5))    # Set bin intervals to 20 and figure size to 5 x 5
plt.xlabel('No of Year 12 Test Takers');                                           # Set x-axis label 
plt.ylabel('No of schools');                                                       # Set y-axis label

# %% [markdown]
# Based on histogram above, majority of schools have lesser then 200 test takers.

# %% [markdown]
# #### Plotting Boxplot

# %%
# Plotting a boxplot of percentage of year 12 students above Math or ERW or both benchmarks

new_sat_2019.boxplot(column=['pct_of_year12_above_both_benchmark','pct_of_year12_above_math_benchmark','pct_of_year12_above_erw_benchmark'])

plt.rcParams["figure.figsize"] = (15,10)    # Set figure size to 15 x 10
plt.ylabel('Percentage')                    # Set y-axis label
plt.title('Boxplots of Percentage of Year 12 students above Math or ERW or Both benchmarks')  # Set title
# Out:
# Text(0.5, 1.0, 'Boxplots of Percentage of Year 12 students above Math or ERW or Both benchmarks')

# %% [markdown]
# Based on the boxplot above, percentage of year 12 above ERW benchmark has a higher median (70%) as compared to percentage of year 12 above math benchmark (45%) and percentage of year 12 above both benchmark (40%).

# %% [markdown]
# #### Plotting Bar Chart

# %% [markdown]
# #### Which California counties is the bottom 5 in terms of median percentage of Year 12 students obtain above benchmark for both Evidence-based Reading and Writing & Math in 2019 SAT test?

# %%
# Save the aggregation result of 'country_name', with median of pct of year12 above both benchmark to a new df "new_sat_2019_agg_county" and sort values in descending order
new_sat_2019_agg_county = new_sat_2019.groupby('county_name')['pct_of_year12_above_both_benchmark'].agg(['median']).sort_values('median',ascending = False)

# %%
#Reset the index of the df
new_sat_2019_agg_county.reset_index(inplace=True)

# %%
# Check the columns of "new_sat_2019_agg_county"
new_sat_2019_agg_county.head()
# Out:
#   county_name  median
# 0    Mariposa   72.22
# 1       Marin   70.91
# 2    Tuolumne   70.00
# 3      Nevada   69.66
# 4      Amador   69.23

# %%
# Plot bar charts of country_name vs median
# Set the figure size to 12 x 12
sns.set(rc={'figure.figsize':(12,12)})

# Plot bar charts of country_name vs median, with blue paleetes, and having title "Median of % of Year 12 students above both SAT subjects benchmark by California County"
ax = sns.barplot(data=new_sat_2019_agg_county,x='median',y='county_name',palette='Blues').set_title(" Median of % of Year 12 students above both SAT subjects benchmark by California County")

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/California_Median_%_Yr12_Students_above_SAT_benchmark.png')

# %% [markdown]
# Among the 53 counties in California, the bottom 5 counties in terms of median % of Year 12 students achieving scores above benchmarks for both subjects:
#
# Colusa - 7.1%
# Glenn – 8.5%
# Fresno – 26.3%
# Los Angeles – 27.9%
# Monterey – 29.3%

# %% [markdown]
# #### Plotting Scatter Plot

# %%
# From the heatmap above, observed r for "% of Year 12 above benchmark for Math" vs "% of Year 12 above benchmark for ERW" is high at 0.91
# Plot a scatter plot to see relationship between the 2
# Establish the size of the figure.
plt.figure(figsize=(9, 9))

# Create scatter plot of "% of Year 12 above benchmark for Math" versus "% of Year 12 above benchmark for ERW".
plt.scatter(new_sat_2019['pct_of_year12_above_erw_benchmark'],
            new_sat_2019['pct_of_year12_above_math_benchmark']);

plt.title("% of Year 12 Above Math Benchmark vs % of Year 12 Above ERW Benchmark");   # Label the plot with title
plt.ylabel("% of Year 12 Above Math Benchmark", fontsize = 20);                       # Label the y axis of plot
plt.xlabel("% of Year 12 Above ERW Benchmark", fontsize = 20);                       # Label the x axis of plot

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/%_Yr12_Students_above_Math_vs_ERW_benchmark.png')

# %% [markdown]
# Based on a correlation study between % of Year 12 above math benchmark vs % of Year 12 above ERW benchmark, there is a strong +ve linear correlation (r=0.91), indicating that students with weak ERW background could possibly have weak Math background as well.

# %% [markdown]
# ### ACT 2019 Data Visualization

# %% [markdown]
# #### Plotting Heatmap

# %%
# Plotting a heatmap for new_act_2019 dataset to visualize correlation between columns
plt.figure(figsize=(14,14))                             # Set the figure size to 14 x 14
sns.set_context('paper',font_scale=1.4)                 # Set context of seaborn to 'paper' and font scale to 1.4

# to create heatmap, need corr matrix
new_act_2019_mx = new_act_2019.corr()                   # Setting up a correlation matrix of the new_act_2019 dataset

sns.heatmap(new_act_2019_mx,annot= True,cmap='Reds')    # Plotting heatmap with annonations, and with cmap in red colour

plt.title('Heatmap for new_act_2019 dataset to visualize correlation between columns')  #Add title to the heatmap
# Out:
# Text(0.5, 1.0, 'Heatmap for new_act_2019 dataset to visualize correlation between columns')

# %% [markdown]
# #### Plotting Histogram

# %%
# Plotting histogram on the number of testtakers for each school
new_act_2019['no_of_testtakers'].plot(kind='hist',bins=20,figsize=(5,5)) # Set bin intervals to 20 and figure size to 5 x 5
plt.xlabel('No of Year 12 Test Takers');                                 # Set x-axis label
plt.ylabel('No of schools');                                             # Set y-axis label

# %% [markdown]
# Based on histogram above, majority of schools have lesser than 100 test takers.

# %% [markdown]
# #### Plotting Boxplot

# %%
# Plotting a boxplot of average scores of students for different subjects in ACT
new_act_2019.boxplot(column=['avg_score_for_reading','avg_score_for_english','avg_score_for_math','avg_score_for_science'])

plt.rcParams["figure.figsize"] = (15,10)      # Set figure size
plt.ylabel('Average Score')                   # Set y-axis label
plt.title('Boxplots of average scores of students for different subjects in ACT')   # Set title
# Out:
# Text(0.5, 1.0, 'Boxplots of average scores of students for different subjects in ACT')

# %% [markdown]
# Based on the boxplot, the median of reading subject is slightly higher the rest of 3 subjects, while the rest of 3 subjects have around similar median at 21.

# %% [markdown]
# #### Plotting Bar Chart

# %% [markdown]
# #### Which California counties is the bottom 5 in terms of median percentage of students obtaining >=21 composite scores in 2019 ACT test?

# %%
# Save the aggregation result of 'country_name', with median of pct_of_testtakers_having_>=21_compositescr to a new df "new_act_2019_agg_county" and sort values in descending order
new_act_2019_agg_county = new_act_2019.groupby('county_name')['pct_of_testtakers_having_>=21_compositescr'].agg(['median']).sort_values('median',ascending = False)

# %%
#Reset the index of the dataframe
new_act_2019_agg_county.reset_index(inplace=True)

# %%
# Check the columns of "new_act_2019_agg_county"
new_act_2019_agg_county.head()
# Out:
#    county_name  median
# 0    Calaveras   84.21
# 1       Shasta   81.68
# 2  Santa Clara   80.46
# 3    San Mateo   80.45
# 4       Amador   79.56

# %%
# Plot bar charts of country_name vs median
# Set the figure size to 12 x 12
sns.set(rc={'figure.figsize':(12,12)})

# Plot bar charts of country_name vs median, with blue paleetes, and having title "Median of % of students obtaining >=21 Composite Score"
ax = sns.barplot(data=new_act_2019_agg_county,x='median',y='county_name',palette='Blues').set_title(" Median of % of students obtaining >=21 Composite Score")

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/California_Median_%_Students_above_21_ACT_Composite.png')

# %% [markdown]
# Among the 53 counties in California, the bottom 5 counties in terms of median % of students obtaining >=21 composite scores:
#
# Modoc – 15.8%
# Fresno – 25.7%
# Monterey – 27.9%
# Tehama – 29.2%
# Lake – 30.6%

# %% [markdown]
# #### Plot Scatter Plot

# %%
# From the heatmap above, observed r for "average score for math" vs "% of students obtaining >=21 Composite Score" is high at 0.95
# Plot a scatter plot to see relationship between the 2
# Establish the size of the figure.
plt.figure(figsize=(5, 5))

# Create scatter plot of "% of Year 12 above benchmark for Math" versus "pct_of_testtakers_having_>=21_compositescr".
plt.scatter(new_act_2019['pct_of_testtakers_having_>=21_compositescr'],
            new_act_2019['avg_score_for_math']);

plt.title("Average score of Math Subject vs % of students obtaining >=21 composite score",fontsize = 10);   # Label the plot with title
plt.ylabel("Average score of Math Subject", fontsize = 10);                                   # Label the y axis of plot
plt.xlabel("% of students obtaining >=21 composite score", fontsize = 10);                    # Label the x axis of plot

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/Math_vs_%_Students_above_21_ACT_Composite.png')

# %%
# From the heatmap above, observed r for "average score for english" vs "% of students obtaining >=21 Composite Score" is high at 0.96
# Plot a scatter plot to see relationship between the 2
# Establish the size of the figure.
plt.figure(figsize=(5, 5))

# Create scatter plot of "% of Year 12 above benchmark for english" versus "pct_of_testtakers_having_>=21_compositescr".
plt.scatter(new_act_2019['pct_of_testtakers_having_>=21_compositescr'],
            new_act_2019['avg_score_for_english']);

plt.title("Average score of English Subject vs % of students obtaining >=21 composite score",fontsize = 10);   # Label the plot with title
plt.ylabel("Average score of English Subject", fontsize = 10);                                   # Label the y axis of plot
plt.xlabel("% of students obtaining >=21 composite score", fontsize = 10);                       # Label the x axis of plot

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/English_vs_%_Students_above_21_ACT_Composite.png')

# %%
# From the heatmap above, observed r for "average score for reading" vs "% of students obtaining >=21 Composite Score" is high at 0.97
# Plot a scatter plot to see relationship between the 2
# Establish the size of the figure.
plt.figure(figsize=(5, 5))

# Create scatter plot of "% of Year 12 above benchmark for reading" versus "pct_of_testtakers_having_>=21_compositescr".
plt.scatter(new_act_2019['pct_of_testtakers_having_>=21_compositescr'],
            new_act_2019['avg_score_for_reading']);

plt.title("Average score of Reading Subject vs % of students obtaining >=21 composite score",fontsize = 10);   # Label the plot with title
plt.ylabel("Average score of Reading Subject", fontsize = 10);                                   # Label the y axis of plot
plt.xlabel("% of students obtaining >=21 composite score", fontsize = 10);                       # Label the x axis of plot

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/Reading_vs_%_Students_above_21_ACT_Composite.png')

# %%
# From the heatmap above, observed r for "average score for science" vs "% of students obtaining >=21 Composite Score" is high at 0.96
# Plot a scatter plot to see relationship between the 2
# Establish the size of the figure.
plt.figure(figsize=(5, 5))

# Create scatter plot of "% of Year 12 above benchmark for science" versus "pct_of_testtakers_having_>=21_compositescr".
plt.scatter(new_act_2019['pct_of_testtakers_having_>=21_compositescr'],
            new_act_2019['avg_score_for_science']);

plt.title("Average score of Science Subject vs % of students obtaining >=21 composite score",fontsize = 10);   # Label the plot with title
plt.ylabel("Average score of Science Subject", fontsize = 10);                                   # Label the y axis of plot
plt.xlabel("% of students obtaining >=21 composite score", fontsize = 10);                       # Label the x axis of plot

# Save the chart
plt.savefig('../Powerpoint_slides/Images Used in Slides/Science_vs_%_Students_above_21_ACT_Composite.png')

# %% [markdown]
# All 4 subjects shows strong +ve linear correlation to % of students obtaining >=21 composite score, suggesting that to increase the % of students obtaining >=21 composite scores, all the 4 subjects are equally important.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# ### SAT Test
#
# <ins>County Analysis</ins>
#
# Government can focus on allocating more and higher quality teaching resources to the bottom 5 counties (Colusa, Glenn, Fresno, Los Angeles and Monterey) in urgent need.
#
# <ins>Subject Analysis</ins>
#
# For students in need, the state will need to provide additional or higher quality teaching resources for both Math and ERW subjects. Throughout the state, government need to improve quality of current teaching resources in Math.
#
# ### ACT Test
# <ins>County Analysis</ins>
#
# Government can focus on allocating more and higher quality teaching resources to the bottom 5 counties in ACT performance, namely Modoc, Fresno, Monterey, Tehama and Lake.
#
# <ins>Subject Analysis</ins>
#
# For students in need, the state will need to provide additional or higher quality teaching resources for all 4 subjects (Math, English, Reading, Science).
